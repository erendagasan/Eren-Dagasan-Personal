# %% [markdown]
# <a href="https://colab.research.google.com/github/erendagasan/Eren-Dagasan-Personal/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bta-lib
# Out:
# Collecting bta-lib
#   Downloading bta_lib-1.0.0-py2.py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bta-lib) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bta-lib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bta-lib) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->bta-lib) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->bta-lib) (1.16.0)
# Installing collected packages: bta-lib
# Successfully installed bta-lib-1.0.0

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import btalib

def calculate_ichimoku(data):
    # Calculate Ichimoku indicators: Tenkan-sen, Kijun-sen, Senkou Span A, Senkou Span B, and Chikou Span
    data['tenkan_sen'] = (data['High'].rolling(window=9).max() + data['Low'].rolling(window=9).min()) / 2
    data['kijun_sen'] = (data['High'].rolling(window=26).max() + data['Low'].rolling(window=26).min()) / 2
    data['senkou_span_a'] = (data['tenkan_sen'] + data['kijun_sen']) / 2
    data['senkou_span_b'] = (data['High'].rolling(window=52).max() + data['Low'].rolling(window=52).min()) / 2
    data['chikou_span'] = data['Close'].shift(-26)  # 26 periods behind
    data['ema_13'] = data['Close'].ewm(span=13).mean()
    data['rsi'] = btalib.rsi(data['Close'], period=14).df

def buy_condition(data, current_index, rsi_threshold=50):
    if current_index < 15:
        return False  # Not enough data for RSI analysis

    current_rsi = data['rsi'][current_index]

    return current_rsi < rsi_threshold

def backtest_strategy(data, initial_balance=10000):
    balance = initial_balance
    position = 0  # 0: no position, 1: long, -1: short
    transactions = []

    for i in range(26, len(data)):
        if (
            data['tenkan_sen'][i] > data['kijun_sen'][i] and
            data['Close'][i] > data['senkou_span_a'][i] and
            data['Close'][i] > data['senkou_span_b'][i] and
            data['Close'][i] > data['ema_13'][i] and
            buy_condition(data, i)
        ):
            # Ichimoku Buy Signal and RSI condition
            if position != 1:
                position = 1
                buy_price = data['Close'][i]
                transactions.append(('Buy', data.index[i], buy_price))
        elif data['tenkan_sen'][i] < data['kijun_sen'][i] and data['Close'][i] < data['senkou_span_a'][i] and data['Close'][i] < data['senkou_span_b'][i]:
            # Ichimoku Sell Signal
            if position != -1:
                position = -1
                sell_price = data['Close'][i]
                transactions.append(('Sell', data.index[i], sell_price))

    # Close any open position at the end
    if position == 1:
        sell_price = data['Close'].iloc[-1]
        transactions.append(('Sell', data.index[-1], sell_price))
    elif position == -1:
        buy_price = data['Close'].iloc[-1]
        transactions.append(('Buy', data.index[-1], buy_price))

    # Calculate final balance
    final_balance = balance + sum([t[2] - initial_balance if t[0] == 'Buy' else initial_balance - t[2] for t in transactions])

    return final_balance, transactions

def main(stock_symbol):
    # Download data
    data = yf.download(stock_symbol, start="2018-01-01", end="2023-01-01")

    # Calculate Ichimoku indicators
    calculate_ichimoku(data)

    # Backtest the strategy
    final_balance, transactions = backtest_strategy(data)

    # Display results
    print(f"Initial Balance: $10,000")
    print(f"Final Balance: ${final_balance:.2f}")
    print("\nTransactions:")
    for transaction in transactions:
        print(transaction)

    # Plot the closing price and Ichimoku indicators
    plt.figure(figsize=(10, 6))
    plt.plot(data['Close'], label='Close Price', color='black')
    plt.plot(data['tenkan_sen'], label='Tenkan-sen', linestyle='--')
    plt.plot(data['kijun_sen'], label='Kijun-sen', linestyle='--')
    plt.plot(data['senkou_span_a'], label='Senkou Span A', linestyle='--')
    plt.plot(data['senkou_span_b'], label='Senkou Span B', linestyle='--')
    plt.plot(data['ema_13'], label='EMA 13', linestyle='--')
    plt.legend()
    plt.title(f"Ichimoku Backtest for {stock_symbol}")
    plt.show()

if __name__ == "__main__":
    stock_symbol = input("Enter the stock symbol (e.g., AAPL): ").upper()
    main(stock_symbol)
# Out:
# Enter the stock symbol (e.g., AAPL): aapl
# [*********************100%%**********************]  1 of 1 completed
# Initial Balance: $10,000
# Final Balance: $3114815.61
#
# Transactions:
# ('Sell', Timestamp('2018-03-28 00:00:00'), 41.619998931884766)
# ('Sell', Timestamp('2018-04-02 00:00:00'), 41.66999816894531)
# ('Sell', Timestamp('2018-04-20 00:00:00'), 41.43000030517578)
# ('Sell', Timestamp('2018-04-23 00:00:00'), 41.310001373291016)
# ('Sell', Timestamp('2018-04-30 00:00:00'), 41.314998626708984)
# ('Sell', Timestamp('2018-10-18 00:00:00'), 54.005001068115234)
# ('Sell', Timestamp('2018-10-24 00:00:00'), 53.772499084472656)
# ('Sell', Timestamp('2018-10-25 00:00:00'), 54.95000076293945)
# ('Sell', Timestamp('2018-10-26 00:00:00'), 54.07500076293945)
# ('Sell', Timestamp('2018-10-29 00:00:00'), 53.060001373291016)
# ('Sell', Timestamp('2018-10-30 00:00:00'), 53.32500076293945)
# ('Sell', Timestamp('2018-11-02 00:00:00'), 51.869998931884766)
# ('Sell', Timestamp('2018-11-05 00:00:00'), 50.397499084472656)
# ('Sell', Timestamp('2018-11-06 00:00:00'), 50.942501068115234)
# ('Sell', Timestamp('2018-11-07 00:00:00'), 52.48749923706055)
# ('Sell', Timestamp('2018-11-08 00:00:00'), 52.122501373291016)
# ('Sell', Timestamp('2018-11-09 00:00:00'), 51.11750030517578)
# ('Sell', Timestamp('2018-11-12 00:00:00'), 48.54249954223633)
# ('Sell', Timestamp('2018-11-13 00:00:00'), 48.057498931884766)
# ('Sell', Timestamp('2018-11-14 00:00:00'), 46.70000076293945)
# ('Sell', Timestamp('2018-11-15 00:00:00'), 47.852500915527344)
# ('Sell', Timestamp('2018-11-16 00:00:00'), 48.38249969482422)
# ('Sell', Timestamp('2018-11-19 00:00:00'), 46.46500015258789)
# ('Sell', Timestamp('2018-11-20 00:00:00'), 44.244998931884766)
# ('Sell', Timestamp('2018-11-21 00:00:00'), 44.19499969482422)
# ('Sell', Timestamp('2018-11-23 00:00:00'), 43.0724983215332)
# ('Sell', Timestamp('2018-11-26 00:00:00'), 43.654998779296875)
# ('Sell', Timestamp('2018-11-27 00:00:00'), 43.560001373291016)
# ('Sell', Timestamp('2018-11-28 00:00:00'), 45.23500061035156)
# ('Sell', Timestamp('2018-11-29 00:00:00'), 44.88750076293945)
# ('Sell', Timestamp('2018-11-30 00:00:00'), 44.64500045776367)
# ('Sell', Timestamp('2018-12-03 00:00:00'), 46.20500183105469)
# ('Sell', Timestamp('2018-12-04 00:00:00'), 44.17250061035156)
# ('Sell', Timestamp('2018-12-06 00:00:00'), 43.68000030517578)
# ('Sell', Timestamp('2018-12-07 00:00:00'), 42.122501373291016)
# ('Sell', Timestamp('2018-12-10 00:00:00'), 42.400001525878906)
# ('Sell', Timestamp('2018-12-11 00:00:00'), 42.157501220703125)
# ('Sell', Timestamp('2018-12-12 00:00:00'), 42.275001525878906)
# ('Sell', Timestamp('2018-12-13 00:00:00'), 42.73749923706055)
# ('Sell', Timestamp('2018-12-14 00:00:00'), 41.369998931884766)
# ('Sell', Timestamp('2018-12-17 00:00:00'), 40.98500061035156)
# ('Sell', Timestamp('2018-12-18 00:00:00'), 41.51750183105469)
# ('Sell', Timestamp('2018-12-19 00:00:00'), 40.22249984741211)
# ('Sell', Timestamp('2018-12-20 00:00:00'), 39.20750045776367)
# ('Sell', Timestamp('2018-12-21 00:00:00'), 37.682498931884766)
# ('Sell', Timestamp('2018-12-24 00:00:00'), 36.70750045776367)
# ('Sell', Timestamp('2018-12-26 00:00:00'), 39.29249954223633)
# ('Sell', Timestamp('2018-12-27 00:00:00'), 39.037498474121094)
# ('Sell', Timestamp('2018-12-28 00:00:00'), 39.057498931884766)
# ('Sell', Timestamp('2018-12-31 00:00:00'), 39.435001373291016)
# ('Sell', Timestamp('2019-01-02 00:00:00'), 39.47999954223633)
# ('Sell', Timestamp('2019-01-03 00:00:00'), 35.54750061035156)
# ('Sell', Timestamp('2019-01-04 00:00:00'), 37.064998626708984)
# ('Sell', Timestamp('2019-01-07 00:00:00'), 36.98249816894531)
# ('Sell', Timestamp('2019-01-08 00:00:00'), 37.6875)
# ('Sell', Timestamp('2019-01-09 00:00:00'), 38.32749938964844)
# ('Sell', Timestamp('2019-01-10 00:00:00'), 38.45000076293945)
# ('Sell', Timestamp('2019-01-11 00:00:00'), 38.0724983215332)
# ('Sell', Timestamp('2019-01-14 00:00:00'), 37.5)
# ('Sell', Timestamp('2019-01-15 00:00:00'), 38.26750183105469)
# ('Sell', Timestamp('2019-01-22 00:00:00'), 38.32500076293945)
# ('Sell', Timestamp('2019-01-23 00:00:00'), 38.47999954223633)
# ('Sell', Timestamp('2019-01-24 00:00:00'), 38.17499923706055)
# ('Sell', Timestamp('2019-05-14 00:00:00'), 47.165000915527344)
# ('Sell', Timestamp('2019-05-15 00:00:00'), 47.72999954223633)
# ('Sell', Timestamp('2019-05-16 00:00:00'), 47.52000045776367)
# ('Sell', Timestamp('2019-05-17 00:00:00'), 47.25)
# ('Sell', Timestamp('2019-05-20 00:00:00'), 45.772499084472656)
# ('Sell', Timestamp('2019-05-21 00:00:00'), 46.650001525878906)
# ('Sell', Timestamp('2019-05-22 00:00:00'), 45.69499969482422)
# ('Sell', Timestamp('2019-05-23 00:00:00'), 44.915000915527344)
# ('Sell', Timestamp('2019-05-24 00:00:00'), 44.74250030517578)
# ('Sell', Timestamp('2019-05-28 00:00:00'), 44.557498931884766)
# ('Sell', Timestamp('2019-05-29 00:00:00'), 44.345001220703125)
# ('Sell', Timestamp('2019-05-30 00:00:00'), 44.57500076293945)
# ('Sell', Timestamp('2019-05-31 00:00:00'), 43.76750183105469)
# ('Sell', Timestamp('2019-06-03 00:00:00'), 43.32500076293945)
# ('Sell', Timestamp('2019-06-04 00:00:00'), 44.90999984741211)
# ('Sell', Timestamp('2019-06-05 00:00:00'), 45.6349983215332)
# ('Sell', Timestamp('2019-06-06 00:00:00'), 46.30500030517578)
# ('Sell', Timestamp('2020-02-25 00:00:00'), 72.0199966430664)
# ('Sell', Timestamp('2020-02-26 00:00:00'), 73.1624984741211)
# ('Sell', Timestamp('2020-02-27 00:00:00'), 68.37999725341797)
# ('Sell', Timestamp('2020-02-28 00:00:00'), 68.33999633789062)
# ('Sell', Timestamp('2020-03-03 00:00:00'), 72.33000183105469)
# ('Sell', Timestamp('2020-03-09 00:00:00'), 66.5425033569336)
# ('Sell', Timestamp('2020-03-10 00:00:00'), 71.33499908447266)
# ('Sell', Timestamp('2020-03-11 00:00:00'), 68.85749816894531)
# ('Sell', Timestamp('2020-03-12 00:00:00'), 62.057498931884766)
# ('Sell', Timestamp('2020-03-13 00:00:00'), 69.49250030517578)
# ('Sell', Timestamp('2020-03-16 00:00:00'), 60.5525016784668)
# ('Sell', Timestamp('2020-03-17 00:00:00'), 63.21500015258789)
# ('Sell', Timestamp('2020-03-18 00:00:00'), 61.66749954223633)
# ('Sell', Timestamp('2020-03-19 00:00:00'), 61.19499969482422)
# ('Sell', Timestamp('2020-03-20 00:00:00'), 57.310001373291016)
# ('Sell', Timestamp('2020-03-23 00:00:00'), 56.092498779296875)
# ('Sell', Timestamp('2020-03-24 00:00:00'), 61.720001220703125)
# ('Sell', Timestamp('2020-03-25 00:00:00'), 61.380001068115234)
# ('Sell', Timestamp('2020-03-27 00:00:00'), 61.935001373291016)
# ('Sell', Timestamp('2020-04-01 00:00:00'), 60.227500915527344)
# ('Sell', Timestamp('2020-04-02 00:00:00'), 61.23249816894531)
# ('Sell', Timestamp('2020-04-03 00:00:00'), 60.352500915527344)
# ('Sell', Timestamp('2020-09-16 00:00:00'), 112.12999725341797)
# ('Sell', Timestamp('2020-09-17 00:00:00'), 110.33999633789062)
# ('Sell', Timestamp('2020-09-18 00:00:00'), 106.83999633789062)
# ('Sell', Timestamp('2020-09-21 00:00:00'), 110.08000183105469)
# ('Sell', Timestamp('2020-09-22 00:00:00'), 111.80999755859375)
# ('Sell', Timestamp('2020-09-23 00:00:00'), 107.12000274658203)
# ('Sell', Timestamp('2020-09-24 00:00:00'), 108.22000122070312)
# ('Sell', Timestamp('2020-09-25 00:00:00'), 112.27999877929688)
# ('Sell', Timestamp('2020-10-02 00:00:00'), 113.0199966430664)
# ('Sell', Timestamp('2020-10-06 00:00:00'), 113.16000366210938)
# ('Sell', Timestamp('2020-10-07 00:00:00'), 115.08000183105469)
# ('Sell', Timestamp('2020-10-08 00:00:00'), 114.97000122070312)
# ('Sell', Timestamp('2020-10-30 00:00:00'), 108.86000061035156)
# ('Sell', Timestamp('2020-11-02 00:00:00'), 108.7699966430664)
# ('Sell', Timestamp('2020-11-03 00:00:00'), 110.44000244140625)
# ('Sell', Timestamp('2021-02-17 00:00:00'), 130.83999633789062)
# ('Sell', Timestamp('2021-02-18 00:00:00'), 129.7100067138672)
# ('Sell', Timestamp('2021-02-19 00:00:00'), 129.8699951171875)
# ('Sell', Timestamp('2021-02-22 00:00:00'), 126.0)
# ('Sell', Timestamp('2021-02-23 00:00:00'), 125.86000061035156)
# ('Sell', Timestamp('2021-02-24 00:00:00'), 125.3499984741211)
# ('Sell', Timestamp('2021-02-25 00:00:00'), 120.98999786376953)
# ('Sell', Timestamp('2021-02-26 00:00:00'), 121.26000213623047)
# ('Sell', Timestamp('2021-03-01 00:00:00'), 127.79000091552734)
# ('Sell', Timestamp('2021-03-02 00:00:00'), 125.12000274658203)
# ('Sell', Timestamp('2021-03-03 00:00:00'), 122.05999755859375)
# ('Sell', Timestamp('2021-03-04 00:00:00'), 120.12999725341797)
# ('Sell', Timestamp('2021-03-05 00:00:00'), 121.41999816894531)
# ('Sell', Timestamp('2021-03-08 00:00:00'), 116.36000061035156)
# ('Sell', Timestamp('2021-03-09 00:00:00'), 121.08999633789062)
# ('Sell', Timestamp('2021-03-10 00:00:00'), 119.9800033569336)
# ('Sell', Timestamp('2021-03-11 00:00:00'), 121.95999908447266)
# ('Sell', Timestamp('2021-03-12 00:00:00'), 121.02999877929688)
# ('Sell', Timestamp('2021-03-15 00:00:00'), 123.98999786376953)
# ('Sell', Timestamp('2021-03-18 00:00:00'), 120.52999877929688)
# ('Sell', Timestamp('2021-03-19 00:00:00'), 119.98999786376953)
# ('Sell', Timestamp('2021-03-22 00:00:00'), 123.38999938964844)
# ('Sell', Timestamp('2021-03-23 00:00:00'), 122.54000091552734)
# ('Sell', Timestamp('2021-03-24 00:00:00'), 120.08999633789062)
# ('Sell', Timestamp('2021-03-25 00:00:00'), 120.58999633789062)
# ('Sell', Timestamp('2021-03-26 00:00:00'), 121.20999908447266)
# ('Sell', Timestamp('2021-03-29 00:00:00'), 121.38999938964844)
# ('Sell', Timestamp('2021-03-30 00:00:00'), 119.9000015258789)
# ('Sell', Timestamp('2021-05-12 00:00:00'), 122.7699966430664)
# ('Sell', Timestamp('2021-05-13 00:00:00'), 124.97000122070312)
# ('Sell', Timestamp('2021-05-17 00:00:00'), 126.2699966430664)
# ('Sell', Timestamp('2021-05-18 00:00:00'), 124.8499984741211)
# ('Sell', Timestamp('2021-05-19 00:00:00'), 124.69000244140625)
# ('Sell', Timestamp('2021-05-20 00:00:00'), 127.30999755859375)
# ('Sell', Timestamp('2021-05-21 00:00:00'), 125.43000030517578)
# ('Sell', Timestamp('2021-05-24 00:00:00'), 127.0999984741211)
# ('Sell', Timestamp('2021-05-25 00:00:00'), 126.9000015258789)
# ('Sell', Timestamp('2021-05-26 00:00:00'), 126.8499984741211)
# ('Sell', Timestamp('2021-05-27 00:00:00'), 125.27999877929688)
# ('Sell', Timestamp('2021-05-28 00:00:00'), 124.61000061035156)
# ('Sell', Timestamp('2021-06-01 00:00:00'), 124.27999877929688)
# ('Sell', Timestamp('2021-06-02 00:00:00'), 125.05999755859375)
# ('Sell', Timestamp('2021-06-03 00:00:00'), 123.54000091552734)
# ('Sell', Timestamp('2021-06-04 00:00:00'), 125.88999938964844)
# ('Sell', Timestamp('2021-06-07 00:00:00'), 125.9000015258789)
# ('Sell', Timestamp('2021-06-08 00:00:00'), 126.73999786376953)
# ('Sell', Timestamp('2021-06-10 00:00:00'), 126.11000061035156)
# ('Sell', Timestamp('2021-09-20 00:00:00'), 142.94000244140625)
# ('Sell', Timestamp('2021-09-21 00:00:00'), 143.42999267578125)
# ('Sell', Timestamp('2021-09-22 00:00:00'), 145.85000610351562)
# ('Sell', Timestamp('2021-09-23 00:00:00'), 146.8300018310547)
# ('Sell', Timestamp('2021-09-24 00:00:00'), 146.9199981689453)
# ('Sell', Timestamp('2021-09-27 00:00:00'), 145.3699951171875)
# ('Sell', Timestamp('2021-09-28 00:00:00'), 141.91000366210938)
# ('Sell', Timestamp('2021-09-29 00:00:00'), 142.8300018310547)
# ('Sell', Timestamp('2021-09-30 00:00:00'), 141.5)
# ('Sell', Timestamp('2021-10-01 00:00:00'), 142.64999389648438)
# ('Sell', Timestamp('2021-10-04 00:00:00'), 139.13999938964844)
# ('Sell', Timestamp('2021-10-05 00:00:00'), 141.11000061035156)
# ('Sell', Timestamp('2021-10-06 00:00:00'), 142.0)
# ('Sell', Timestamp('2021-10-07 00:00:00'), 143.2899932861328)
# ('Sell', Timestamp('2021-10-08 00:00:00'), 142.89999389648438)
# ('Sell', Timestamp('2021-10-11 00:00:00'), 142.80999755859375)
# ('Sell', Timestamp('2021-10-12 00:00:00'), 141.50999450683594)
# ('Sell', Timestamp('2021-10-13 00:00:00'), 140.91000366210938)
# ('Sell', Timestamp('2021-10-14 00:00:00'), 143.75999450683594)
# ('Sell', Timestamp('2022-01-20 00:00:00'), 164.50999450683594)
# ('Sell', Timestamp('2022-01-21 00:00:00'), 162.41000366210938)
# ('Sell', Timestamp('2022-01-24 00:00:00'), 161.6199951171875)
# ('Sell', Timestamp('2022-01-25 00:00:00'), 159.77999877929688)
# ('Sell', Timestamp('2022-01-26 00:00:00'), 159.69000244140625)
# ('Sell', Timestamp('2022-01-27 00:00:00'), 159.22000122070312)
# ('Sell', Timestamp('2022-02-24 00:00:00'), 162.74000549316406)
# ('Sell', Timestamp('2022-03-01 00:00:00'), 163.1999969482422)
# ('Sell', Timestamp('2022-03-07 00:00:00'), 159.3000030517578)
# ('Sell', Timestamp('2022-03-08 00:00:00'), 157.44000244140625)
# ('Sell', Timestamp('2022-03-09 00:00:00'), 162.9499969482422)
# ('Sell', Timestamp('2022-03-10 00:00:00'), 158.52000427246094)
# ('Sell', Timestamp('2022-03-11 00:00:00'), 154.72999572753906)
# ('Sell', Timestamp('2022-03-14 00:00:00'), 150.6199951171875)
# ('Sell', Timestamp('2022-03-15 00:00:00'), 155.08999633789062)
# ('Sell', Timestamp('2022-03-16 00:00:00'), 159.58999633789062)
# ('Sell', Timestamp('2022-04-22 00:00:00'), 161.7899932861328)
# ('Sell', Timestamp('2022-04-25 00:00:00'), 162.8800048828125)
# ('Sell', Timestamp('2022-04-26 00:00:00'), 156.8000030517578)
# ('Sell', Timestamp('2022-04-27 00:00:00'), 156.57000732421875)
# ('Sell', Timestamp('2022-04-28 00:00:00'), 163.63999938964844)
# ('Sell', Timestamp('2022-04-29 00:00:00'), 157.64999389648438)
# ('Sell', Timestamp('2022-05-02 00:00:00'), 157.9600067138672)
# ('Sell', Timestamp('2022-05-03 00:00:00'), 159.47999572753906)
# ('Sell', Timestamp('2022-05-05 00:00:00'), 156.77000427246094)
# ('Sell', Timestamp('2022-05-06 00:00:00'), 157.27999877929688)
# ('Sell', Timestamp('2022-05-09 00:00:00'), 152.05999755859375)
# ('Sell', Timestamp('2022-05-10 00:00:00'), 154.50999450683594)
# ('Sell', Timestamp('2022-05-11 00:00:00'), 146.5)
# ('Sell', Timestamp('2022-05-12 00:00:00'), 142.55999755859375)
# ('Sell', Timestamp('2022-05-13 00:00:00'), 147.11000061035156)
# ('Sell', Timestamp('2022-05-16 00:00:00'), 145.5399932861328)
# ('Sell', Timestamp('2022-05-17 00:00:00'), 149.24000549316406)
# ('Sell', Timestamp('2022-05-18 00:00:00'), 140.82000732421875)
# ('Sell', Timestamp('2022-05-19 00:00:00'), 137.35000610351562)
# ('Sell', Timestamp('2022-05-20 00:00:00'), 137.58999633789062)
# ('Sell', Timestamp('2022-05-23 00:00:00'), 143.11000061035156)
# ('Sell', Timestamp('2022-05-24 00:00:00'), 140.36000061035156)
# ('Sell', Timestamp('2022-05-25 00:00:00'), 140.52000427246094)
# ('Sell', Timestamp('2022-05-26 00:00:00'), 143.77999877929688)
# ('Sell', Timestamp('2022-06-03 00:00:00'), 145.3800048828125)
# ('Sell', Timestamp('2022-06-06 00:00:00'), 146.13999938964844)
# ('Sell', Timestamp('2022-06-09 00:00:00'), 142.63999938964844)
# ('Sell', Timestamp('2022-06-10 00:00:00'), 137.1300048828125)
# ('Sell', Timestamp('2022-06-13 00:00:00'), 131.8800048828125)
# ('Sell', Timestamp('2022-06-14 00:00:00'), 132.75999450683594)
# ('Sell', Timestamp('2022-06-15 00:00:00'), 135.42999267578125)
# ('Sell', Timestamp('2022-06-16 00:00:00'), 130.05999755859375)
# ('Sell', Timestamp('2022-06-17 00:00:00'), 131.55999755859375)
# ('Sell', Timestamp('2022-06-21 00:00:00'), 135.8699951171875)
# ('Sell', Timestamp('2022-06-22 00:00:00'), 135.35000610351562)
# ('Sell', Timestamp('2022-06-28 00:00:00'), 137.44000244140625)
# ('Sell', Timestamp('2022-06-30 00:00:00'), 136.72000122070312)
# ('Sell', Timestamp('2022-07-01 00:00:00'), 138.92999267578125)
# ('Sell', Timestamp('2022-09-06 00:00:00'), 154.52999877929688)
# ('Sell', Timestamp('2022-09-08 00:00:00'), 154.4600067138672)
# ('Sell', Timestamp('2022-09-13 00:00:00'), 153.83999633789062)
# ('Sell', Timestamp('2022-09-14 00:00:00'), 155.30999755859375)
# ('Sell', Timestamp('2022-09-15 00:00:00'), 152.3699951171875)
# ('Sell', Timestamp('2022-09-16 00:00:00'), 150.6999969482422)
# ('Sell', Timestamp('2022-09-19 00:00:00'), 154.47999572753906)
# ('Sell', Timestamp('2022-09-20 00:00:00'), 156.89999389648438)
# ('Sell', Timestamp('2022-09-21 00:00:00'), 153.72000122070312)
# ('Sell', Timestamp('2022-09-22 00:00:00'), 152.74000549316406)
# ('Sell', Timestamp('2022-09-23 00:00:00'), 150.42999267578125)
# ('Sell', Timestamp('2022-09-26 00:00:00'), 150.77000427246094)
# ('Sell', Timestamp('2022-09-27 00:00:00'), 151.75999450683594)
# ('Sell', Timestamp('2022-09-28 00:00:00'), 149.83999633789062)
# ('Sell', Timestamp('2022-09-29 00:00:00'), 142.47999572753906)
# ('Sell', Timestamp('2022-09-30 00:00:00'), 138.1999969482422)
# ('Sell', Timestamp('2022-10-03 00:00:00'), 142.4499969482422)
# ('Sell', Timestamp('2022-10-04 00:00:00'), 146.10000610351562)
# ('Sell', Timestamp('2022-10-05 00:00:00'), 146.39999389648438)
# ('Sell', Timestamp('2022-10-06 00:00:00'), 145.42999267578125)
# ('Sell', Timestamp('2022-10-07 00:00:00'), 140.08999633789062)
# ('Sell', Timestamp('2022-10-10 00:00:00'), 140.4199981689453)
# ('Sell', Timestamp('2022-10-11 00:00:00'), 138.97999572753906)
# ('Sell', Timestamp('2022-10-12 00:00:00'), 138.33999633789062)
# ('Sell', Timestamp('2022-10-13 00:00:00'), 142.99000549316406)
# ('Sell', Timestamp('2022-10-14 00:00:00'), 138.3800048828125)
# ('Sell', Timestamp('2022-10-17 00:00:00'), 142.41000366210938)
# ('Sell', Timestamp('2022-10-18 00:00:00'), 143.75)
# ('Sell', Timestamp('2022-10-20 00:00:00'), 143.38999938964844)
# ('Sell', Timestamp('2022-12-15 00:00:00'), 136.5)
# ('Sell', Timestamp('2022-12-16 00:00:00'), 134.50999450683594)
# ('Sell', Timestamp('2022-12-19 00:00:00'), 132.3699951171875)
# ('Sell', Timestamp('2022-12-20 00:00:00'), 132.3000030517578)
# ('Sell', Timestamp('2022-12-21 00:00:00'), 135.4499969482422)
# ('Sell', Timestamp('2022-12-22 00:00:00'), 132.22999572753906)
# ('Sell', Timestamp('2022-12-23 00:00:00'), 131.86000061035156)
# ('Sell', Timestamp('2022-12-27 00:00:00'), 130.02999877929688)
# ('Sell', Timestamp('2022-12-28 00:00:00'), 126.04000091552734)
# ('Sell', Timestamp('2022-12-29 00:00:00'), 129.61000061035156)
# ('Sell', Timestamp('2022-12-30 00:00:00'), 129.92999267578125)
# ('Sell', Timestamp('2023-01-03 00:00:00'), 125.06999969482422)
# ('Sell', Timestamp('2023-01-04 00:00:00'), 126.36000061035156)
# ('Sell', Timestamp('2023-01-05 00:00:00'), 125.0199966430664)
# ('Sell', Timestamp('2023-01-06 00:00:00'), 129.6199951171875)
# ('Sell', Timestamp('2023-01-09 00:00:00'), 130.14999389648438)
# ('Sell', Timestamp('2023-01-10 00:00:00'), 130.72999572753906)
# ('Sell', Timestamp('2023-08-04 00:00:00'), 181.99000549316406)
# ('Sell', Timestamp('2023-08-07 00:00:00'), 178.85000610351562)
# ('Sell', Timestamp('2023-08-08 00:00:00'), 179.8000030517578)
# ('Sell', Timestamp('2023-08-09 00:00:00'), 178.19000244140625)
# ('Sell', Timestamp('2023-08-10 00:00:00'), 177.97000122070312)
# ('Sell', Timestamp('2023-08-11 00:00:00'), 177.7899932861328)
# ('Sell', Timestamp('2023-08-14 00:00:00'), 179.4600067138672)
# ('Sell', Timestamp('2023-08-15 00:00:00'), 177.4499969482422)
# ('Sell', Timestamp('2023-08-16 00:00:00'), 176.57000732421875)
# ('Sell', Timestamp('2023-08-17 00:00:00'), 174.0)
# ('Sell', Timestamp('2023-08-18 00:00:00'), 174.49000549316406)
# ('Sell', Timestamp('2023-08-21 00:00:00'), 175.83999633789062)
# ('Sell', Timestamp('2023-08-22 00:00:00'), 177.22999572753906)
# ('Sell', Timestamp('2023-08-24 00:00:00'), 176.3800048828125)
# ('Sell', Timestamp('2023-08-25 00:00:00'), 178.61000061035156)
# ('Sell', Timestamp('2023-08-28 00:00:00'), 180.19000244140625)
# ('Sell', Timestamp('2023-09-06 00:00:00'), 182.91000366210938)
# ('Sell', Timestamp('2023-09-07 00:00:00'), 177.55999755859375)
# ('Sell', Timestamp('2023-09-08 00:00:00'), 178.17999267578125)
# ('Sell', Timestamp('2023-09-20 00:00:00'), 175.49000549316406)
# ('Sell', Timestamp('2023-09-21 00:00:00'), 173.92999267578125)
# ('Sell', Timestamp('2023-09-22 00:00:00'), 174.7899932861328)
# ('Sell', Timestamp('2023-09-25 00:00:00'), 176.0800018310547)
# ('Sell', Timestamp('2023-09-26 00:00:00'), 171.9600067138672)
# ('Sell', Timestamp('2023-09-27 00:00:00'), 170.42999267578125)
# ('Sell', Timestamp('2023-09-28 00:00:00'), 170.69000244140625)
# ('Sell', Timestamp('2023-09-29 00:00:00'), 171.2100067138672)
# ('Sell', Timestamp('2023-10-02 00:00:00'), 173.75)
# ('Sell', Timestamp('2023-10-03 00:00:00'), 172.39999389648438)
# ('Sell', Timestamp('2023-10-04 00:00:00'), 173.66000366210938)
# ('Sell', Timestamp('2023-10-05 00:00:00'), 174.91000366210938)
# /usr/local/lib/python3.10/dist-packages/btalib/meta/lines.py:302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trailer = trailprefix.append(series[p2:])
# /usr/local/lib/python3.10/dist-packages/btalib/meta/lines.py:302: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   trailer = trailprefix.append(series[p2:])
